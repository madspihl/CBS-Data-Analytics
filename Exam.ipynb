# %%
import pandas as pd
vaccines = pd.read_csv("Vaccine_Hesitancy_for_COVID-19__County_and_local_estimates.csv")

# Shape
print("Number of instances and attributes: {}".format(vaccines.shape))

# Dropping useless columns
vaccines.drop(['County Boundary', 'State Boundary'], axis = 1, inplace = True)

# Sort by Coun
vaccines.sort_values('State')
# Out:
# Number of instances and attributes: (3142, 20)
#       FIPS Code                       County Name           State  \
# 2487      45001  Abbeville County, South Carolina  SOUTH CAROLINA
# 1276      22001          Acadia Parish, Louisiana       LOUISIANA
# 2853      51001         Accomack County, Virginia        VIRGINIA
# 769       16001                 Ada County, Idaho           IDAHO
# 1074      19001                Adair County, Iowa            IOWA
# ...         ...                               ...             ...
# 237        4027              Yuma County, Arizona         ARIZONA
# 613        8125             Yuma County, Colorado        COLORADO
# 2890      48505              Zapata County, Texas           TEXAS
# 2867      48507              Zavala County, Texas           TEXAS
# 2516      46137      Ziebach County, South Dakota    SOUTH DAKOTA
#
#       Estimated hesitant  Estimated strongly hesitant  \
# 2487                0.19                         0.09
# ...
